# %%
import pandas as pd
import polars as pl

# Set options to display all rows and columns
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
data_path = "./data/meps_2023/"
main_df = "h251.xlsx"

# %%
# reading file usng polars for faster speed
df_pl1 = pl.read_excel(f"%s%s" % (data_path, main_df))
# print(df_pl1.columns)

# %%
keep_cols = [
    # --- Identifiers ---
    "DUPERSID",
    # --- Demographics & SES ---
    "AGELAST",
    "SEX",
    "RACEV1X",
    "RACETHX",
    "HISPANX",
    "EDUCYR",
    "FAMINC23",
    "POVCAT23",
    "INSCOV23",
    "INSURC23",
    "REGION23",
    # --- Nativity / Language (optional but useful) ---
    "BORNUSA",
    "YRSINUS",
    # --- Health status ---
    "RTHLTH53",
    "MNHLTH53",
    "ADSMOK42",
    # --- Chronic conditions ---
    "HIBPDX",
    "CHDDX",
    "ASTHDX",
    "DIABDX_M18",
    # --- Utilization ---
    "OBTOTV23",
    "OPTOTV23",
    "ERTOT23",
    "DVTOT23",
    "TOTEXP23",
    # --- Hospitalization indicators / target sources ---
    "IPDIS23",
    "IPTEXP23",
    "IPNGTD23",
]

# %%
rename_map = {
    # Identifiers
    "DUPERSID": "person_id",
    # Demographics & SES
    "AGELAST": "age",
    "SEX": "sex",
    "RACEV1X": "race_simple",
    "RACETHX": "race_ethnicity",
    "HISPANX": "hispanic",
    "EDUCYR": "education_years",
    "FAMINC23": "family_income",
    "POVCAT23": "poverty_category",
    "INSCOV23": "insurance_coverage",
    "INSURC23": "insurance_category",
    "REGION23": "region",
    # Nativity / Language
    "BORNUSA": "born_in_usa",
    "YRSINUS": "years_in_us",
    # Health status
    "RTHLTH53": "self_rated_health",
    "MNHLTH53": "self_rated_mental_health",
    "ADSMOK42": "smoker",
    # Chronic conditions
    "HIBPDX": "hypertension_dx",
    "CHDDX": "coronary_hd_dx",
    "ASTHDX": "asthma_dx",
    "DIABDX_M18": "diabetes_dx",
    # Utilization
    "OBTOTV23": "office_visits",
    "OPTOTV23": "outpatient_visits",
    "ERTOT23": "er_visits",
    "DVTOT23": "total_visits",
    "TOTEXP23": "total_expenditures",
    # Hospitalization indicators / sources
    "IPDIS23": "inpatient_discharges",
    "IPTEXP23": "inpatient_expenditures",
    "IPNGTD23": "inpatient_nights",
}

# %%
df_pl = df_pl1[keep_cols]
df_pl = df_pl.rename(rename_map)

display(df_pl.head())
# Out:
# shape: (5, 29)
# ┌────────────┬─────┬─────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ person_id  ┆ age ┆ sex ┆ race_simple ┆ … ┆ total_expen ┆ inpatient_d ┆ inpatient_e ┆ inpatient_n │
# │ ---        ┆ --- ┆ --- ┆ ---         ┆   ┆ ditures     ┆ ischarges   ┆ xpenditures ┆ ights       │
# │ str        ┆ i64 ┆ i64 ┆ i64         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ ---         │
# │            ┆     ┆     ┆             ┆   ┆ i64         ┆ i64         ┆ i64         ┆ i64         │
# ╞════════════╪═════╪═════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 2790002101 ┆ 58  ┆ 2   ┆ 2           ┆ … ┆ 646         ┆ 0           ┆ 0           ┆ 0           │
# │ 2790002102 ┆ 27  ┆ 1   ┆ 2           ┆ … ┆ 1894        ┆ 0           ┆ 0           ┆ 0           │
# │ 2790004101 ┆ 49  ┆ 2   ┆ 1           ┆ … ┆ 986         ┆ 0           ┆ 0           ┆ 0           │
# │ 2790006101 ┆ 75  ┆ 2   ┆ 1           ┆ … ┆ 1312        ┆ 0           ┆ 0           ┆ 0           │
# │ 2790006102 ┆ 23  ┆ 1   ┆ 1           ┆ … ┆ 0           ┆ 0           ┆ 0           ┆ 0           │
# └────────────┴─────┴─────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
df_pd = df_pl.to_pandas()

# %%
categorical_cols = [
    "sex",
    "race_simple",
    "race_ethnicity",
    "hispanic",
    "poverty_category",
    "insurance_coverage",
    "insurance_category",
    "region",
    "born_in_usa",
    "self_rated_health",
    "self_rated_mental_health",
    "smoker",
    "hypertension_dx",
    "coronary_hd_dx",
    "asthma_dx",
    "diabetes_dx",
]

# %%
df_ohe_pd = pd.get_dummies(
    df_pd,
    columns=categorical_cols,
    drop_first=False,
)

# %%
df_ohe_pd["hospitalized"] = (df_ohe_pd["inpatient_expenditures"] > 0).astype(int)

# %%
print(df_ohe_pd["hospitalized"].value_counts(normalize=True))
# Out:
# hospitalized
# 0    0.926265
# 1    0.073735
# Name: proportion, dtype: float64

# %%
df_ohe_pd.shape
print(df_ohe_pd.head(1))
# Out:
#     person_id  age  education_years  family_income  years_in_us  \
# 0  2790002101   58               17         130700           -1
#
#    office_visits  outpatient_visits  er_visits  total_visits  \
# 0              3                  1          0             0
#
#    total_expenditures  inpatient_discharges  inpatient_expenditures  \
# 0                 646                     0                       0
#
#    inpatient_nights  sex_1  sex_2  race_simple_1  race_simple_2  \
# 0                 0  False   True          False           True
#
#    race_simple_3  race_simple_4  race_simple_6  race_ethnicity_1  \
# 0          False          False          False             False
#
#    race_ethnicity_2  race_ethnicity_3  race_ethnicity_4  race_ethnicity_5  \
# 0             False              True             False             False
#
#    hispanic_1  hispanic_2  poverty_category_1  poverty_category_2  \
# 0       False        True               False               False
#
#    poverty_category_3  poverty_category_4  poverty_category_5  \
# 0               False               False                True
#
#    insurance_coverage_1  insurance_coverage_2  insurance_coverage_3  \
# 0                  True                 False                 False
#
#    insurance_category_1  insurance_category_2  insurance_category_3  \
# 0                  True                 False                 False
#
#    insurance_category_4  insurance_category_5  insurance_category_6  \
# 0                 False                 False                 False
#
#    insurance_category_7  insurance_category_8  region_-1  region_1  region_2  \
# 0                 False                 False      False     False      True
#
#    region_3  region_4  born_in_usa_-8  born_in_usa_-7  born_in_usa_-1  \
# 0     False     False           False           False           False
#
#    born_in_usa_1  born_in_usa_2  self_rated_health_-8  self_rated_health_-7  \
# 0           True          False                 False                 False
#
#    self_rated_health_-1  self_rated_health_1  self_rated_health_2  \
# 0                 False                False                False
#
#    self_rated_health_3  self_rated_health_4  self_rated_health_5  \
# 0                False                 True                False
#
#    self_rated_mental_health_-8  self_rated_mental_health_-7  \
# 0                        False                        False
#
#    self_rated_mental_health_-1  self_rated_mental_health_1  \
# 0                        False                       False
#
#    self_rated_mental_health_2  self_rated_mental_health_3  \
# 0                       False                        True
#
#    self_rated_mental_health_4  self_rated_mental_health_5  smoker_-15  \
# 0                       False                       False       False
#
#    smoker_-1  smoker_1  smoker_2  hypertension_dx_-8  hypertension_dx_-7  \
# 0      False     False      True               False               False
#
#    hypertension_dx_-1  hypertension_dx_1  hypertension_dx_2  \
# 0               False              False               True
#
#    coronary_hd_dx_-8  coronary_hd_dx_-7  coronary_hd_dx_-1  coronary_hd_dx_1  \
# 0              False              False              False             False
#
#    coronary_hd_dx_2  asthma_dx_-8  asthma_dx_-7  asthma_dx_-1  asthma_dx_1  \
# 0              True         False         False         False        False
#
#    asthma_dx_2  diabetes_dx_-8  diabetes_dx_-7  diabetes_dx_-1  diabetes_dx_1  \
# 0         True           False           False           False           True
#
#    diabetes_dx_2  hospitalized
# 0          False             0

# %%
df_ohe_pd.info()
df_ohe_pd.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18919 entries, 0 to 18918
# Data columns (total 94 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   person_id                    18919 non-null  object
#  1   age                          18919 non-null  int64
#  2   education_years              18919 non-null  int64
#  3   family_income                18919 non-null  int64
#  4   years_in_us                  18919 non-null  int64
#  5   office_visits                18919 non-null  int64
#  6   outpatient_visits            18919 non-null  int64
#  7   er_visits                    18919 non-null  int64
#  8   total_visits                 18919 non-null  int64
#  9   total_expenditures           18919 non-null  int64
#  10  inpatient_discharges         18919 non-null  int64
#  11  inpatient_expenditures       18919 non-null  int64
#  12  inpatient_nights             18919 non-null  int64
#  13  sex_1                        18919 non-null  bool
#  14  sex_2                        18919 non-null  bool
#  15  race_simple_1                18919 non-null  bool
#  16  race_simple_2                18919 non-null  bool
#  17  race_simple_3                18919 non-null  bool
#  18  race_simple_4                18919 non-null  bool
#  19  race_simple_6                18919 non-null  bool
#  20  race_ethnicity_1             18919 non-null  bool
#  21  race_ethnicity_2             18919 non-null  bool
#  22  race_ethnicity_3             18919 non-null  bool
#  23  race_ethnicity_4             18919 non-null  bool
#  24  race_ethnicity_5             18919 non-null  bool
#  25  hispanic_1                   18919 non-null  bool
#  26  hispanic_2                   18919 non-null  bool
#  27  poverty_category_1           18919 non-null  bool
#  28  poverty_category_2           18919 non-null  bool
#  29  poverty_category_3           18919 non-null  bool
#  30  poverty_category_4           18919 non-null  bool
#  31  poverty_category_5           18919 non-null  bool
#  32  insurance_coverage_1         18919 non-null  bool
#  33  insurance_coverage_2         18919 non-null  bool
#  34  insurance_coverage_3         18919 non-null  bool
#  35  insurance_category_1         18919 non-null  bool
#  36  insurance_category_2         18919 non-null  bool
#  37  insurance_category_3         18919 non-null  bool
#  38  insurance_category_4         18919 non-null  bool
#  39  insurance_category_5         18919 non-null  bool
#  40  insurance_category_6         18919 non-null  bool
#  41  insurance_category_7         18919 non-null  bool
#  42  insurance_category_8         18919 non-null  bool
#  43  region_-1                    18919 non-null  bool
#  44  region_1                     18919 non-null  bool
#  45  region_2                     18919 non-null  bool
#  46  region_3                     18919 non-null  bool
#  47  region_4                     18919 non-null  bool
#  48  born_in_usa_-8               18919 non-null  bool
#  49  born_in_usa_-7               18919 non-null  bool
#  50  born_in_usa_-1               18919 non-null  bool
#  51  born_in_usa_1                18919 non-null  bool
#  52  born_in_usa_2                18919 non-null  bool
#  53  self_rated_health_-8         18919 non-null  bool
#  54  self_rated_health_-7         18919 non-null  bool
#  55  self_rated_health_-1         18919 non-null  bool
#  56  self_rated_health_1          18919 non-null  bool
#  57  self_rated_health_2          18919 non-null  bool
#  58  self_rated_health_3          18919 non-null  bool
#  59  self_rated_health_4          18919 non-null  bool
#  60  self_rated_health_5          18919 non-null  bool
#  61  self_rated_mental_health_-8  18919 non-null  bool
#  62  self_rated_mental_health_-7  18919 non-null  bool
#  63  self_rated_mental_health_-1  18919 non-null  bool
#  64  self_rated_mental_health_1   18919 non-null  bool
#  65  self_rated_mental_health_2   18919 non-null  bool
#  66  self_rated_mental_health_3   18919 non-null  bool
#  67  self_rated_mental_health_4   18919 non-null  bool
#  68  self_rated_mental_health_5   18919 non-null  bool
#  69  smoker_-15                   18919 non-null  bool
#  70  smoker_-1                    18919 non-null  bool
#  71  smoker_1                     18919 non-null  bool
#  72  smoker_2                     18919 non-null  bool
#  73  hypertension_dx_-8           18919 non-null  bool
#  74  hypertension_dx_-7           18919 non-null  bool
#  75  hypertension_dx_-1           18919 non-null  bool
#  76  hypertension_dx_1            18919 non-null  bool
#  77  hypertension_dx_2            18919 non-null  bool
#  78  coronary_hd_dx_-8            18919 non-null  bool
#  79  coronary_hd_dx_-7            18919 non-null  bool
#  80  coronary_hd_dx_-1            18919 non-null  bool
#  81  coronary_hd_dx_1             18919 non-null  bool
#  82  coronary_hd_dx_2             18919 non-null  bool
#  83  asthma_dx_-8                 18919 non-null  bool
#  84  asthma_dx_-7                 18919 non-null  bool
#  85  asthma_dx_-1                 18919 non-null  bool
#  86  asthma_dx_1                  18919 non-null  bool
#  87  asthma_dx_2                  18919 non-null  bool
#  88  diabetes_dx_-8               18919 non-null  bool
#  89  diabetes_dx_-7               18919 non-null  bool
#  90  diabetes_dx_-1               18919 non-null  bool
#  91  diabetes_dx_1                18919 non-null  bool
#  92  diabetes_dx_2                18919 non-null  bool
#  93  hospitalized                 18919 non-null  int64
# dtypes: bool(80), int64(13), object(1)
# memory usage: 3.5+ MB
#                           count          mean           std    min      25%  \
# age                     18919.0     43.716581     23.939550    0.0     23.0
# education_years         18919.0     11.218405      5.497385   -8.0      9.0
# family_income           18919.0  98815.895555  91575.419638 -230.0  35000.0
# years_in_us             18919.0     -0.148528      2.087025   -8.0     -1.0
# office_visits           18919.0      7.140758     13.784344    0.0      0.0
# outpatient_visits       18919.0      1.095195      4.489569    0.0      0.0
# er_visits               18919.0      0.224166      0.672914    0.0      0.0
# total_visits            18919.0      1.035943      1.688402    0.0      0.0
# total_expenditures      18919.0   8422.054125  21664.250470    0.0    299.5
# inpatient_discharges    18919.0      0.096728      0.394552    0.0      0.0
# inpatient_expenditures  18919.0   1830.599397  11540.246170    0.0      0.0
# inpatient_nights        18919.0      0.535599      4.267027    0.0      0.0
# hospitalized            18919.0      0.073735      0.261347    0.0      0.0
#
#                             50%       75%       max
# age                        45.0      64.0      85.0
# education_years            12.0      16.0      17.0
# family_income           72800.0  137484.0  747346.0
# years_in_us                -1.0      -1.0       5.0
# office_visits               2.0       8.0     419.0
# outpatient_visits           0.0       1.0     178.0
# er_visits                   0.0       0.0      22.0
# total_visits                0.0       2.0      25.0
# total_expenditures       1816.0    7087.0  574675.0
# inpatient_discharges        0.0       0.0      10.0
# inpatient_expenditures      0.0       0.0  458360.0
# inpatient_nights            0.0       0.0     264.0
# hospitalized                0.0       0.0       1.0

# %%
corr = df_ohe_pd.corr(numeric_only=True)["hospitalized"].sort_values(ascending=False)
print(corr)
# Out:
# hospitalized                   1.000000
# inpatient_discharges           0.865864
# inpatient_expenditures         0.562237
# total_expenditures             0.451419
# inpatient_nights               0.444087
# er_visits                      0.416078
# age                            0.175374
# hypertension_dx_1              0.164760
# coronary_hd_dx_1               0.155536
# self_rated_mental_health_-1    0.150579
# self_rated_health_-1           0.150579
# outpatient_visits              0.146469
# office_visits                  0.141957
# diabetes_dx_1                  0.126824
# region_-1                      0.117282
# self_rated_health_5            0.115014
# insurance_category_4           0.109697
# self_rated_health_4            0.107225
# insurance_coverage_2           0.106903
# insurance_category_6           0.103033
# insurance_category_5           0.068628
# self_rated_mental_health_4     0.064495
# race_ethnicity_2               0.050264
# asthma_dx_1                    0.049784
# education_years                0.048283
# self_rated_mental_health_5     0.048248
# hispanic_2                     0.048134
# born_in_usa_-1                 0.046369
# poverty_category_1             0.043531
# smoker_2                       0.036987
# asthma_dx_-1                   0.036803
# diabetes_dx_-1                 0.036803
# sex_2                          0.033845
# poverty_category_2             0.033351
# self_rated_health_3            0.021446
# born_in_usa_1                  0.021163
# self_rated_mental_health_3     0.014955
# poverty_category_3             0.014830
# race_ethnicity_3               0.014397
# smoker_1                       0.013931
# smoker_-15                     0.013646
# race_simple_1                  0.012551
# race_simple_2                  0.012452
# region_2                       0.012073
# coronary_hd_dx_2               0.009142
# insurance_category_8           0.005984
# region_1                       0.005400
# race_simple_3                  0.002147
# region_3                       0.000437
# self_rated_mental_health_-8   -0.001251
# asthma_dx_-8                  -0.002560
# born_in_usa_-8                -0.005428
# born_in_usa_-7                -0.006161
# hypertension_dx_-7            -0.006805
# coronary_hd_dx_-7             -0.006805
# self_rated_health_-8          -0.007678
# insurance_category_2          -0.007947
# asthma_dx_-7                  -0.008209
# diabetes_dx_-7                -0.008209
# diabetes_dx_-8                -0.008707
# race_simple_6                 -0.008839
# insurance_category_7          -0.009405
# coronary_hd_dx_-8             -0.009627
# race_ethnicity_5              -0.009822
# hypertension_dx_-8            -0.011055
# self_rated_mental_health_-7   -0.014080
# self_rated_health_-7          -0.014230
# poverty_category_4            -0.018697
# years_in_us                   -0.021011
# born_in_usa_2                 -0.025597
# total_visits                  -0.030923
# race_simple_4                 -0.033425
# race_ethnicity_4              -0.033686
# sex_1                         -0.033845
# poverty_category_5            -0.039609
# region_4                      -0.040249
# smoker_-1                     -0.047015
# hispanic_1                    -0.048134
# race_ethnicity_1              -0.048134
# self_rated_mental_health_2    -0.048274
# self_rated_mental_health_1    -0.052956
# asthma_dx_2                   -0.054932
# insurance_category_3          -0.055755
# insurance_coverage_3          -0.056574
# family_income                 -0.064968
# self_rated_health_2           -0.069120
# insurance_coverage_1          -0.074276
# hypertension_dx_2             -0.077299
# coronary_hd_dx_-1             -0.090791
# hypertension_dx_-1            -0.090791
# self_rated_health_1           -0.098844
# insurance_category_1          -0.114370
# diabetes_dx_2                 -0.129851
# Name: hospitalized, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report

# 1. Define X and y
cols_to_drop = [
    "hospitalized",
    "person_id",
    "inpatient_expenditures",
    "inpatient_nights",
    "inpatient_discharges",
]

X = df_ohe_pd.drop(columns=[c for c in cols_to_drop if c in df_ohe_pd.columns])
y = df_ohe_pd["hospitalized"]

# 2. Train/test split (stratified due to imbalance)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y,
)

# 3. Baseline logistic regression with class weights (handles imbalance)
log_clf = LogisticRegression(
    max_iter=1000,
    class_weight="balanced",
    n_jobs=-1,
)

log_clf.fit(X_train, y_train)

# 4. Evaluate
y_pred = log_clf.predict(X_test)
y_proba = log_clf.predict_proba(X_test)[:, 1]

print("ROC-AUC:", roc_auc_score(y_test, y_proba))
print(classification_report(y_test, y_pred))
# Out:
# ROC-AUC: 0.9511513967909093
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      4381
#            1       0.41      0.89      0.56       349
#
#     accuracy                           0.90      4730
#    macro avg       0.70      0.89      0.75      4730
# weighted avg       0.95      0.90      0.91      4730
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import precision_recall_curve

prec, rec, thresh = precision_recall_curve(y_test, y_proba)

# %%
# Convert the clean Polars table (with renamed columns) to pandas
df_meta = df_pl.select(
    [
        "person_id",
        "age",
        "sex",
        "race_ethnicity",
        "hispanic",
        "poverty_category",
        "insurance_coverage",
        "family_income",
        "self_rated_health",
        "self_rated_mental_health",
        "hospitalized",
    ]
).to_pandas()
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Convert the clean Polars table (with renamed columns) to pandas
# ----> 2 df_meta = df_pl.select(
#       3     [
#       4         "person_id",
#       5         "age",
#       6         "sex",
#       7         "race_ethnicity",
#       8         "hispanic",
#       9         "poverty_category",
#      10         "insurance_coverage",
#      11         "family_income",
#      12         "self_rated_health",
#      13         "self_rated_mental_health",
#      14         "hospitalized",
#      15     ]
#      16 ).to_pandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/dataframe/frame.py:10007, in DataFrame.select(self, *exprs, **named_exprs)
#    9923 """
#    9924 Select columns from this DataFrame.
#    9925
#    (...)
#   10000 └───────────┘
#   10001 """
#   10002 from polars.lazyframe.opt_flags import QueryOptFlags
#   10004 return (
#   10005     self.lazy()
#   10006     .select(*exprs, **named_exprs)
# > 10007     .collect(optimizations=QueryOptFlags._eager())
#   10008 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/lazyframe/opt_flags.py:330, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     329 kwargs["optimizations"] = optflags
# --> 330 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/lazyframe/frame.py:2407, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2405 # Only for testing purposes
#    2406 callback = _kwargs.get("post_opt_callback", callback)
# -> 2407 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: unable to find column "hospitalized"; valid columns: ["person_id", "age", "sex", "race_simple", "race_ethnicity", "hispanic", "education_years", "family_income", "poverty_category", "insurance_coverage", "insurance_category", "region", "born_in_usa", "years_in_us", "self_rated_health", "self_rated_mental_health", "smoker", "hypertension_dx", "coronary_hd_dx", "asthma_dx", "diabetes_dx", "office_visits", "outpatient_visits", "er_visits", "total_visits", "total_expenditures", "inpatient_discharges", "inpatient_expenditures", "inpatient_nights"]

# %%
# Attach predictions to the fairness meta table
df_meta["pred_prob"] = log_clf.predict_proba(X)[:, 1]
df_meta["pred_label"] = log_clf.predict(X)
